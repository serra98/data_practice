# %%
import pandas as pd

# %%
file_path = './data_set/prac.csv' #using coderpad file

# %%
df = pd.read_csv(file_path)

# %%
#first 5 rows 
df.head(5)
#first 100 rows 
df.head(100)
# Out:
#      id      company_name               company_website          region  \
# 0     1          Internxt         https://internxt.com/           Spain
# 1     2          Dockflow          https://dockflow.com         Belgium
# 2     3         api.video             https://api.video          France
# 3     4           Buck.ai              https://buck.ai/   United States
# 4     5         Prodsight      https://www.prodsight.ai  United Kingdom
# ..  ...               ...                           ...             ...
# 95   96     Joby Aviation  http://www.jobyaviation.com/   United States
# 96   97             Gojek         https://www.gojek.io/       Indonesia
# 97   98  Impossible Foods  https://impossiblefoods.com/   United States
# 98   99             Bakkt         https://www.bakkt.com   United States
# 99  100            Lilium           https://lilium.com/         Germany
#
#                    vertical  funding_amount_usd funding_stage funding_date
# 0                Blockchain              571184          Seed       Jan-20
# 1                 Logistics                   0          Seed       Jan-20
# 2            Developer APIs              300000          Seed       Jan-20
# 3   Artificial Intelligence              300000          Seed       Jan-20
# 4   Artificial Intelligence              529013          Seed       Jan-20
# ..                      ...                 ...           ...          ...
# 95                Aerospace           590000000      Series C       Jan-20
# 96            Food Delivery          1200000000      Series G       Mar-20
# 97        Food and Beverage           500000000      Series F       Mar-20
# 98               Blockchain           300000000      Series B       Mar-20
# 99       Air Transportation           240000000      Series C       Mar-20
#
# [100 rows x 8 columns]

# %%
# 2. Get max funding_amount
max_funding = df['funding_amount_usd'].max()
print("\nMax funding amount:", max_funding)
# Out:
# Max funding amount: 1901446920

# %%
# 3. Get avg funding_amount per company_name (assuming one entry per company in this CSV)
avg_funding_per_company = df.groupby('company_name')['funding_amount_usd'].mean()
print("\nAverage funding amount per company:")
print(avg_funding_per_company)
# Out:
# Average funding amount per company:
# company_name
# 1Huddle         5000000.0
# 1sm              375000.0
# 1touch.io      14000000.0
# 2021.AI         1500000.0
# 360VUZ          6000000.0
#                   ...
# neptune.ai      3000000.0
# onetool          900000.0
# proteanTecs    45000000.0
# quantilope     28000000.0
# ÅURA          28000000.0
# Name: funding_amount_usd, Length: 979, dtype: float64

# %%
# 4. Get highest avg funding_amount per company_name where country = "United States"
us_companies = df[df['region'] == 'United States']
highest_avg_funding_us = us_companies.groupby('company_name')['funding_amount_usd'].mean().max()
print("\nHighest average funding amount for a company in the United States:")
print(highest_avg_funding_us)
# Out:
# Highest average funding amount for a company in the United States:
# 1901446920.0

# %%
# looks like .mean() is changing value to float and so I would like to round it up 
# back to 3 
avg_funding_per_company = df.groupby('company_name')['funding_amount_usd'].mean().round().astype(int)
print("\nAverage funding amount per company:")
print(avg_funding_per_company)
# Out:
# Average funding amount per company:
# company_name
# 1Huddle         5000000
# 1sm              375000
# 1touch.io      14000000
# 2021.AI         1500000
# 360VUZ          6000000
#                  ...
# neptune.ai      3000000
# onetool          900000
# proteanTecs    45000000
# quantilope     28000000
# ÅURA          28000000
# Name: funding_amount_usd, Length: 979, dtype: int64

# %%
#possible errors to look out for 
#If there are multiple entries for a single company, this will compute the average funding for that company. 
#Possible Name Inconsistencies: If company names have inconsistencies (example: 'Apple Inc.' vs 'Apple'), this will be treated separate companies, but we want to keep this as same companies.  This can affect the accuracy of your results.
#We couldusing data from Clearbit API or ZoomInfo API - apis that could potentially provide us unique id per company would help us detect the same companies with differnt names or we could also implement our own logic to keep these companies as one consistent company. 
#ways for us to do that would be - checking case sensitivity, checking with company_website 

help_rename = df.groupby('company_website')['company_name'].first().to_dict()
df['company_name'] = df['company_website'].map(help_rename)

# 3. Get avg funding_amount per company_name (rounded to whole number)
avg_funding_per_company = df.groupby('company_name')['funding_amount_usd'].mean().round().astype(int)
print("\nAverage funding amount per company:")
print(avg_funding_per_company)
# Out:
# Average funding amount per company:
# company_name
# 1Huddle         5000000
# 1sm              375000
# 1touch.io      14000000
# 2021.AI         1500000
# 360VUZ          6000000
#                  ...
# neptune.ai      3000000
# onetool          900000
# proteanTecs    45000000
# quantilope     28000000
# ÅURA          28000000
# Name: funding_amount_usd, Length: 979, dtype: int64

# %%
#back to 4 
us_companies = df[df['region'] == 'United States']
highest_avg_funding_us = us_companies.groupby('company_name')['funding_amount_usd'].mean().round().astype(int).max()
print("\nHighest average funding amount for a company in the United States:")
print(highest_avg_funding_us)
# Out:
# Highest average funding amount for a company in the United States:
# 1901446920

# %%
# checking possible errors
# Missing Values or Null values -> we should try to keep it in standard uniform way. 

print("Unique company names in us_companies:")
print(us_companies['company_name'].unique())

print("Unique region:")
print(df['region'].unique())

#checking if funding_amount_usd has any non integer value 
print("Unique region:")
print(df['funding_amount_usd'].unique())
# Out:
# Unique company names in us_companies:
# ['Buck.ai' 'Seatrec' 'BeeCanvas' 'SmartKarrot' 'Fundraise Up' 'Yac'
#  'Cloverleaf.me' 'Docket' 'Podsights' 'SIMBA Chain' 'Defendify'
#  'OpenPhone' 'Punch List' 'Kloud.io' 'Upflex' '1Huddle' 'Luxury Presence'
#  'Lynq' 'Stoplight' 'TypingDNA' 'Ceterus' 'AppOmni' 'Containous'
#  'Legalpad' 'Neighbor' 'Otter.ai' 'AbSci' 'Feathr' 'Locale' 'Lily AI'
#  'BlueConic' 'Spatial' 'Roambee' 'Insurify' 'MURAL' 'Clubhouse' 'CREXi'
#  'Workboard' 'Modern Health' 'Verbit.ai' 'Productboard' 'Justworks'
#  'SECURITI.ai' 'LaunchDarkly' 'Element Biosciences' 'Verkada'
#  'ActiveCampaign' 'Sisense' 'Joby Aviation' 'Impossible Foods' 'Bakkt'
#  'Via' 'HashiCorp' 'ElevateBio' 'UserTesting' 'Lyra Health'
#  'Rigetti Computing' 'Everlaw' 'Netlify' 'SpotOn' 'mParticle' 'Proxy'
#  'Human Interest' 'Rancher Labs' 'STRIVR' 'Orion Labs' 'Sensel' 'Remesh'
#  'Airbase' 'Sourcegraph' 'Arkose Labs' 'Pager' 'Fast' 'Leaf Logistics'
#  'Suki' 'Mya Systems' 'Second Nature' 'Validere' 'Axis Security' 'Helm.ai'
#  'Deepgram' 'Quit Genius' 'Rollbar' 'UnitQ' 'Slync.io' 'Finix' 'Forager'
#  'Moffett' 'Ride Report' 'ZeroNorth' 'DisruptOPS' 'Allset' 'Cleanshelf'
#  'Zeto' 'Yaguara' 'Pathlight' 'Around' 'BackboneAI' 'ProCredEx'
#  'Balancer Labs' 'Zabo' 'ZBiotics' 'Sounder.fm' 'Strata' 'SalesReach'
#  'mod.io' 'Hallo' 'Aspen Neuroscience' 'Concertio' 'Phantom AI'
#  'SonderMind' 'Everstream Solutions' 'MixMode' 'Cadence' 'Arturo'
#  'AlertMedia' 'Shippo' 'CircleCI' 'Podium' 'Sila' 'IFM Restoration'
#  'Tonkean' 'Wellpay' 'SeeQC' 'Kate Farms' 'Bugcrowd' 'Thrasio' 'Cohesity'
#  'Cloosiv' 'Atlas AI' 'Clever Leaves' 'Beyond Identity' 'Rallybio'
#  'Gembah' 'Alkira' 'Coder' 'Awake Security' 'Attentive' 'Learn In'
#  'Everee' 'Parsyl' 'Greenbits' 'Stripe' 'Benepass' '360VUZ' 'Unlearn'
#  'Guru' 'env0' 'Oyster' 'Biobot Analytics' 'Federated Wireless' 'Vercel'
#  'ForgeRock' 'Confluent' 'Hugo' 'XRHealth' 'Remote' 'Noah' 'Randori'
#  'Digits' 'Miro' 'AvidXchange' 'Corsight AI' 'CureMint' 'Walrus.ai'
#  'Omura' 'Brain Corp' 'Topia' 'Tecton' 'Catalyst' 'Niche.com'
#  'Mojo Vision' 'Josh.ai' 'Figma' 'XWING' 'BeeHero' 'Invisible AI' 'Vise'
#  'Deep Labs' 'Lilt' 'FortressIQ' 'Paradox' 'Directly' 'DefinedCrowd'
#  'Datch' 'Waymo' 'ASAPP' 'Procore' 'Instabug' 'Daily.co' 'Jellyfish'
#  'Postal.io' 'Sleuth' 'Knock' 'Stardog' 'Groove' 'IntelliBoard' 'Briq'
#  'UpKeep' 'MemSQL' 'Truework' 'Bevy' 'Deel' 'BetterCloud' 'RapidAPI'
#  'Brainbase' 'Amplitude' 'Command E' 'Encamp' 'Run The World' 'FullStory'
#  'Spectrm' 'Gatsby' 'Census' 'Baton' 'LaterPay' 'RudderStack' 'Nanit'
#  'SQZ Biotech' 'ChromaCode' 'Benchling' 'NEAR' 'Lolli' 'Blockdaemon'
#  'FalconX' 'TokenSoft' 'Magic' 'Charityvest' 'GigaSpaces' 'Virtana'
#  'DigitalOcean' 'Couchbase' 'Skyflow' 'Enview' 'MakeSpace' 'Coalition'
#  'Synack' 'Tugboat Logic' 'Nautilus Data' 'Yardbird' 'Bluecore' 'Tapcart'
#  'Ecwid' 'Quizlet' 'MasterClass' 'Tankfarm' 'Robinhood' 'Treasury Prime'
#  'Clyde' 'Aspiration' 'Brex' 'Unifimoney' 'Fundbox' 'Tock' 'Mindstrong'
#  'Tia' 'Insitro' 'VNDLY' 'Compt' 'Workstream' 'Almanac' 'DispatchTrack'
#  'AerialSphere' 'Stringr' 'Homeward' 'States Title' 'Spruce Holdings'
#  'SmartRent' 'Traitify' 'SVT Robotics' 'Covariant' 'Tripgrid'
#  'Big Sky Health' 'Ezra AI' 'Bonusly' 'Spaced Ventures' 'Vetty'
#  'Locus Robotics' '1touch.io' 'Anvil' 'Betterview' 'Lili' 'Varo Money'
#  'CAST AI' 'Hyperscience' 'Inky' 'ClassTag' 'Chargeback' 'Squire'
#  'DNAnexus' 'Yugabyte' 'M1 Finance' 'Planck' 'EnsoData' 'Canopy'
#  'Transcend' 'Flatfile' 'Domino Data Lab' 'Vendr' 'Cue' 'NS8'
#  'Intellispark' 'Protera' 'Alpha Health' 'RapidSOS' 'SuperAnnotate'
#  'Postman' 'Quolum' 'Ethyca' 'Headspace' 'WiBotic' 'Augmedics'
#  'Shattuck Labs' 'Kalderos' 'Localised' 'Streamlit' 'Clockwise'
#  'DeepSource' 'Starburst' 'Salt Security' 'Hydrow' 'Akia' 'IonQ' 'Onna'
#  'Arena.im' 'River Financial' 'Unum ID' 'DroneBase' 'Pagaya Investments'
#  'Botkeeper' 'HASH' 'Urbint' 'Maystreet' 'Acquire' 'Big Health'
#  'Kaia Health' 'CrossTower' 'Rasa' 'Urjanet' 'Nylas' 'Humanly'
#  'BrightInsight' 'ClickUp' 'Cape Privacy' 'Lightrun' 'Trusting Social'
#  'Pipe' 'OJO' 'HelloOffice' 'FireStart' 'Capital Markets Gateway' 'Karat'
#  'Candidate Labs' 'Codefresh' 'Area 1 Security' 'Cynet' 'Aclaimant'
#  'Nacelle' 'Fivetran' 'Discord' 'Scalefast' 'NexHealth' 'Upsolver'
#  'Elementary Robotics' 'Bluedot' 'Capital' 'Pattern89'
#  'Anduril Industries' 'Density' 'Huddl' 'Shelf Engine' 'Signum.ai'
#  'Simply Speak' 'FraudScope' 'Sea Machines Robotics' 'Sibros' 'Mosaic'
#  'Turbo Systems' 'Hevo Data' 'Chorus.ai' 'boostr' 'Paragon' 'Ceros' 'effx'
#  'Epsagon' 'Grid Raster' 'Matik' 'Quorum' 'Sift' 'Talkdesk' 'Macro'
#  'Openpath' 'MadKudu' 'Qumulo' 'Lattice' '1sm' 'Quaestor' 'Puppet'
#  'Trackstreet' 'VideoPeel' 'TileDB' 'Tenovos' 'Jika' 'LogDNA' 'onetool'
#  'OwnBackup' 'SetSail' 'Zomentum' 'ChannelMeter' 'Glympse Bio' 'Qualio'
#  'Adagio Therapeutics' 'Teller Finance' 'Chainalysis' 'Curv'
#  'Stack Overflow' 'Cover Technologies' 'Eterneva' 'Nasuni' 'Ermetic'
#  'RangeForce' 'Whistic' 'Sotero' 'Auth0' 'Second Front Systems' 'Vendia'
#  'Skydio' 'CALA' 'Bolt' 'TeleTeachers' 'Guideline' 'Remitly' 'Mantl'
#  'Meemo' 'Privacy.com' 'Bond' 'Icon' 'Point Card' 'Ready, Set, Food!'
#  'Crisp' 'Mori' 'Athlane' 'Ro' 'Kindbody' 'Truepill' 'Opus' 'Angle Health'
#  'Hippo' 'Start Sure' 'Dispatch' 'Instrumental' 'Torre' 'Kernel' 'Turing'
#  'Gem' 'Jobcase' 'The Mom Project' 'Competitive Wedge' 'Replenysh'
#  'Dexterity' 'CY Vision' 'Immertec' 'The Browser Company' 'Tempo' 'Real'
#  'Ergatta' 'SpaceX' 'Truera' 'Syntiant' 'Hiretual' 'LitLingo'
#  'Sift Healthcare' 'Aetion' 'Dataiku' 'VertaAI' 'WorkPatterns' 'AgentSync'
#  'BRIO' 'Mode Analytics' 'PandaDoc' 'Yotpo' 'Coda' 'Compaas' 'Fyllo'
#  'Gong' 'GoSite' 'Oomnitza' 'Parabola' 'RevenueCat' 'Simpplr' 'Stream'
#  'Bridge Connector' 'Yalo' 'CaliberMind' 'SupportLogic' 'Blanket'
#  'Chili Piper' 'Reflective' 'Stedi' 'Berbix' 'ChartHop' 'LaunchNotes'
#  'Split' 'Stratify Technologies' 'Synthego' 'BlockFi' 'Restream' 'Craft'
#  'Dutchie' 'Frontline' 'Feather' 'HyperQube' 'Censys' 'Clean Creative'
#  'Blumira' 'Elisity' 'Cyware Labs' 'SpyCloud' 'ReliaQuest' 'Merico' 'Mux'
#  'Qonversion' 'WayScript' 'Pachyderm' 'Grafana Labs' 'ReturnLogic'
#  'Pattern' 'Narrativ' 'GoPeer' 'Skillshare' 'Lambda School' 'CleverX'
#  'Juni Learning' 'Xos Trucks' 'SiFive' 'Ceresa' 'Orum.io' 'Axle' 'SMBX'
#  'Trumid' 'Moov' 'CommonStock' 'Cross River' 'Esusu' 'Machnet'
#  'Atomo Coffee' 'Atari' 'ROOM' 'Eden Health' 'OneDrop' 'PatientPop'
#  'Minnow' 'Rippling' 'Carrot Fertility' 'Flux' 'HelloTeam' 'Welcome'
#  'Republic' 'Sesh' 'TemperPack' 'Zibo' 'ICON' 'Joblist' 'Candidate'
#  'XYZ Robotics' 'Leaf Agriculture' 'Justpoint' 'YesPlz' 'WhyLabs'
#  'Replicant' 'Golden' 'Legion' 'Biofourmis' 'Beyond Limits' 'XtalPi'
#  'Zymergen' 'Camera IQ' 'Pliant.io' 'AppDirect' 'Avo' 'Plantt' 'Ribbon'
#  'Collective' 'InCountry' 'Reachdesk' 'Shelf' 'Air' 'Courier' 'Laika'
#  'SquadStack' 'BrandTotal']
# Unique region:
# ['Spain' 'Belgium' 'France' 'United States' 'United Kingdom' 'Turkey'
#  'Australia' 'Japan' 'Israel' 'Poland' 'Switzerland' 'Canada' 'India'
#  'Germany' 'Austria' 'Finland' 'South Korea' 'Sweden' 'Indonesia' 'China'
#  'Lithuania' 'Nigeria' 'Singapore' 'Denmark' 'Ukraine'
#  'United Arab Emirates' 'Hong Kong' 'Estonia' 'Ireland' 'Greece' 'Cyprus'
#  'The Netherlands' 'Italy' 'Luxembourg' 'Mexico' 'South Africa'
#  'Bangladesh' 'Norway' 'Thailand' 'Brazil' 'Colombia' 'Portugal'
#  'Cambodia' 'Iceland' nan 'Taiwan']
# Unique region:
# [    571184          0     300000     529013     650000     970000
#     1000000    1100000    1250000    1300000    1500000    1544561
#     1955982    2000000    2204536    2751321    3000000    3500000
#     3904358    4000000    4100000    4300000    5000000    5400000
#     6000000    6511001    7000000    7500000    8300000    8796728
#     9100000   10000000   10021155   10400000   10500000   11000000
#    12000000   12500000   12800000   14000000   14140964   15200000
#    19954857   20000000   22000000   22300000   23000000   24000000
#    25000000   26000000   30000000   31000000   45000000   47000000
#    50000000   54000000   70000000   75000000   80000000   97500000
#   100000000  115000000  590000000 1200000000  500000000  300000000
#   240000000  200000000  175000000  170000000  150000000   71000000
#    62000000   58000000   53000000   42000000   40000000   29000000
#    28700000   28000000   23500000   19000000   18700000   17500000
#    16399999   15000000   13000000   11800000   10800000    9000000
#     8199999    8000000    7300000    7200000    6600000    5200000
#     4900000    4700000    4500000    3600000    3300000    2500000
#     2300000    2200000    2100000    1800000    1200000     900000
#      850000     660000     600000     500000     268000     614000
#   125000000   57000000  113000000  230000000   35000000   21000000
#    27000000  343000000     185000  250000000   93000000     702000
#    36000000   41000000  145000000     400000   65000000  600000000
#    94000000  128000000   16000000   51000000   46000000   52000000
#   750000000  185000000  190000000  105000000   17000000   90000000
#      575000  280000000  149000000  135000000   49000000   37000000
#   143000000  144000000   85000000  123000000   60000000    7790000
#    18000000     150000   76168932   28126792  241000000   18029001
#     7664035  281703154    5800000     565202     100000    3513022
#     3259291   33000000    1907983    7600000   43000000    5600000
#      220000    2750000   13500000   23863121   47700000    5700000
#   118000000    6500000    3397166     830000    2600000   75935717
#    38297612     820758  102000000    6400000   39000000     104562
#     2819433    2750130   14650000    8861385     800000   22625304
#     2350000   39400000    2250225   62500000   11215389    4486155
#     4650000    4643171    4600000    6160169    4800000   13300000
#    12700000    2471424    1683743   32000000     375000   44000000
#   120000000     470000     330000  320000000   38000000     862000
#   316000000  260000000     420000   56000000 1901446920   10250000
#     5100000    2800000    4400000    1900000    3700000     700000
#     4250000     451278   25500000   20251157   11932638   47174818
#     1315067   11400000   15500000    2960727     328766     109663
#    66000000   74000000    3783937     250000     520000   61000000
#      341002    6542438    5500000    3292770    1310779    9700000
#   106000000      40000    3550241   34700000    1400000  110000000
#      648501    1585000    3552873    4287903    2374278   11807393
#     1035000    1350000    1510000    1700000   14500000  133000000
#   318800000    6771144   14683209    1298958    1163872    1092147
#     8650000   15100000    3422297   10100000    5542426]
